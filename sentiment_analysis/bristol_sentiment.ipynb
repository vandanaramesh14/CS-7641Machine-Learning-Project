# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import RegexpTokenizer
from langdetect import detect
from langdetect import detect_langs
import numpy as np
import seaborn as sns
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from wordcloud import WordCloud
#nltk.downloader.download('vader_lexicon')
#nltk.download('stopwords')
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')

# %%
df = pd.read_csv('./Bristol/bristol_reviews.csv')
df_test = df.head(n=100)

# %% [markdown]
# ### 1. Cleaning reviews file (filter out nulls and non-english reviews)

# %%
#df_input = df_test
df_input = df
df_input.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0       70820   8163487  2013-10-18      7538116       Neralee
# 1       70820   8397676  2013-10-28      9601180         Terry
# 2       70820   8706695  2013-11-12      9697980         Alice
# 3       70820  13024371  2014-05-17      2388955        Thomas
# 4       70820  14247963  2014-06-15     16317003     Dimitrije
#
#                                             comments
# 0  We loved our stay with Sarah in Bristol. She w...
# 1  Sarah gave us and Laddie our dog a very warm w...
# 2  Exactly as described on the site and praised b...
# 3  Sarah was great. She was warm and welcoming, e...
# 4  The experience was really great at Sarah's hou...

# %%
# classify language of review
def get_language(x):
    try:
        language = detect(x)
    except:
        language = "error"

    return language

# %%
df_input['language'] = df_input["comments"].apply(get_language)

# %%
# save file with language classification to csv 
df_input.to_csv('./Bristol/bristol_reviews_language.csv', index=False)

# %%
df_input.shape
# Out:
# (71520, 7)

# %%
df_input.groupby('language').count()
# Out:
#           listing_id     id   date  reviewer_id  reviewer_name  comments
# language
# af                79     79     79           79             79        79
# ca               115    115    115          115            115       115
# cs                44     44     44           44             44        44
# cy                19     19     19           19             19        19
# da                22     22     22           22             22        22
# de               403    403    403          403            403       403
# el                 5      5      5            5              5         5
# en             67991  67991  67991        67991          67991     67991
# error            146    146    146          146            146       110
# es               604    604    604          604            604       604
# et                10     10     10           10             10        10
# fi                17     17     17           17             17        17
# fr               994    994    994          994            994       994
# hr                11     11     11           11             11        11
# hu                27     27     27           27             27        27
# id                15     15     15           15             15        15
# it               292    292    292          292            292       292
# ja                 8      8      8            8              8         8
# ko                72     72     72           72             72        72
# nl                96     96     96           96             96        96
# no                27     27     27           27             27        27
# pl                24     24     24           24             24        24
# pt                42     42     42           42             42        42
# ro               142    142    142          142            142       142
# ru                12     12     12           12             12        12
# sk                 4      4      4            4              4         4
# sl                 4      4      4            4              4         4
# so                84     84     84           84             84        84
# sq                 1      1      1            1              1         1
# sv                14     14     14           14             14        14
# sw                13     13     13           13             13        13
# tl                24     24     24           24             24        24
# tr                 3      3      3            3              3         3
# vi                 4      4      4            4              4         4
# zh-cn            150    150    150          150            150       150
# zh-tw              2      2      2            2              2         2

# %%
plt.figure(figsize = (8,5))
sns.color_palette("husl", 8)
sns.set_palette('husl')
sns.set_style("darkgrid")
sns.countplot(x='language', data=df_input, order=pd.value_counts(df_input['language']).iloc[:10].index)

# %% [markdown]
# ## 2. Run sentiment analysis on english reviews only

# %%
# run sentiment analysis on english reviews only 
df_english = df_input.loc[df_input['language'] == 'en']
df_english.shape
# Out:
# (67991, 7)

# %%
ss = SentimentIntensityAnalyzer()

# %%
def apply_sentiment(val, ss):
    val = str(val)
    return ss.polarity_scores(val)['compound']

# %%
df_english['sentiment'] = df_english['comments'].apply(apply_sentiment, ss = ss)
# Out:
# <ipython-input-13-e48b027d7231>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_english['sentiment'] = df_english['comments'].apply(apply_sentiment, ss = ss)

# %%
df_english.to_csv('./Bristol/bristol_sentiment.csv',index = False)

# %%
df_english.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0       70820   8163487  2013-10-18      7538116       Neralee
# 1       70820   8397676  2013-10-28      9601180         Terry
# 2       70820   8706695  2013-11-12      9697980         Alice
# 3       70820  13024371  2014-05-17      2388955        Thomas
# 4       70820  14247963  2014-06-15     16317003     Dimitrije
#
#                                             comments language  sentiment
# 0  We loved our stay with Sarah in Bristol. She w...       en     0.9861
# 1  Sarah gave us and Laddie our dog a very warm w...       en     0.8712
# 2  Exactly as described on the site and praised b...       en     0.9336
# 3  Sarah was great. She was warm and welcoming, e...       en     0.9873
# 4  The experience was really great at Sarah's hou...       en     0.9875

# %% [markdown]
# ## 3. Create new features based on positive and negative reviews

# %%
df_sent = df_english[['listing_id', 'sentiment']]
df_sent.reset_index(inplace=True)
del df_sent['index']

# %%
# create new column with positive and negative classifications
def sentiment_classification(x):
    if x >= 0.05 : 
        classification = 'positive' 
  
    elif x <= - 0.05 : 
        classification = 'negative'
  
    else : 
        classification = 'neutral'
    return classification
  
df_sent['sentiment_class'] = df_sent['sentiment'].apply(sentiment_classification)
df_sent.head()
# Out:
# <ipython-input-17-9c187e4199fe>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sent['sentiment_class'] = df_sent['sentiment'].apply(sentiment_classification)
#    listing_id  sentiment sentiment_class
# 0       70820     0.9861        positive
# 1       70820     0.8712        positive
# 2       70820     0.9336        positive
# 3       70820     0.9873        positive
# 4       70820     0.9875        positive

# %%
#create two new features, avg_sentiment_score and proportion_positive

def pos_proportion(x):
    v = np.sum(x=='positive')/len(x)
    return v 

df_avg_sent = df_sent.groupby('listing_id', group_keys = False, as_index = False).agg({
    'sentiment': np.mean,
    'sentiment_class' : pos_proportion})

# %%
df_avg_sent.head()
# Out:
#    listing_id  sentiment  sentiment_class
# 0       70820   0.870781         0.993103
# 1      117122   0.917494         0.992857
# 2      176306   0.822666         0.947368
# 3      307634   0.871122         0.944444
# 4      322906   0.909380         0.962025

# %%
df_avg_sent.rename(columns={'sentiment': 'avg_sentiment_score', 'sentiment_class': 'proportion_positive'}, inplace=True)
df_avg_sent.to_csv('./Bristol/bristol_sentiment_features.csv', index = False)

# %% [markdown]
# ## Exploratory sentiment analysis

# %%
df_neighborhoods = pd.read_csv('../data_input/Amsterdam/amsterdam_listings_full.csv')
df_neighborhoods.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   2818   https://www.airbnb.com/rooms/2818  20201009050447   2020-10-11
# 1  20168  https://www.airbnb.com/rooms/20168  20201009050447   2020-10-11
# 2  25428  https://www.airbnb.com/rooms/25428  20201009050447   2020-10-11
# 3  27886  https://www.airbnb.com/rooms/27886  20201009050447   2020-10-10
# 4  28871  https://www.airbnb.com/rooms/28871  20201009050447   2020-10-10
#
#                                                 name  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1       Studio with private bathroom in the centre 1
# 2    Lovely apt in City Centre (w.lift) near Jordaan
# 3  Romantic, stylish B&B houseboat in canal district
# 4                            Comfortable double room
#
#                                          description  \
# 0  Quiet Garden View Room & Super Fast WiFi<br />...
# 1  17th century Dutch townhouse in the heart of t...
# 2  Lovely apt in Centre ( lift & fireplace) near ...
# 3  Stylish and romantic houseboat on fantastic hi...
# 4  <b>The space</b><br />In a monumental house ri...
#
#                                neighborhood_overview  \
# 0  Indische Buurt ("Indies Neighborhood") is a ne...
# 1  Located just in between famous central canals....
# 2                                                NaN
# 3         Central, quiet, safe, clean and beautiful.
# 4       Flower market , Leidseplein , Rembrantsplein
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/10272854/8dcc...     3159
# 1  https://a0.muscache.com/pictures/69979628/fd6a...    59484
# 2  https://a0.muscache.com/pictures/138431/7079a9...    56142
# 3  https://a0.muscache.com/pictures/02c2da9d-660e...    97647
# 4  https://a0.muscache.com/pictures/160889/362340...   124245
#
#                                    host_url  ... review_scores_communication  \
# 0    https://www.airbnb.com/users/show/3159  ...                        10.0
# 1   https://www.airbnb.com/users/show/59484  ...                        10.0
# 2   https://www.airbnb.com/users/show/56142  ...                        10.0
# 3   https://www.airbnb.com/users/show/97647  ...                        10.0
# 4  https://www.airbnb.com/users/show/124245  ...                        10.0
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                    9.0                10.0     NaN                t
# 1                   10.0                 9.0     NaN                t
# 2                   10.0                10.0     NaN                f
# 3                   10.0                10.0     NaN                t
# 4                   10.0                10.0     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           0
# 1                              2                                           0
# 2                              1                                           1
# 3                              1                                           0
# 4                              2                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            2
# 2                                            0
# 3                                            1
# 4                                            2
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.98
# 1                                           0              2.63
# 2                                           0              0.15
# 3                                           0              2.05
# 4                                           0              2.72
#
# [5 rows x 74 columns]

# %%
df = pd.read_csv('./Amsterdam/amsterdam_sentiment.csv')
df_neighborhoods = pd.read_csv('../data_input/Amsterdam/amsterdam_listings_full.csv')
df_neighborhoods = df_neighborhoods[['id', 'neighbourhood_group_cleansed']]
df_neighborhoods.head()
# Out:
#       id  neighbourhood_group_cleansed
# 0   2818                           NaN
# 1  20168                           NaN
# 2  25428                           NaN
# 3  27886                           NaN
# 4  28871                           NaN

# %% [markdown]
# ### Show sentiment by borough

# %%
df_merged = pd.merge(df, df_neighborhoods,  how='left', left_on=['listing_id'], right_on = ['id'])
df_merged.head()
# Out:
#    listing_id     id_x        date  reviewer_id reviewer_name  \
# 0        2595    19760  2009-12-10        38960         Anita
# 1        2595    34320  2010-04-09        71130       Kai-Uwe
# 2        2595    46312  2010-05-25       117113        Alicia
# 3        2595  1238204  2012-05-07      1783688        Sergey
# 4        2595  1293632  2012-05-17      1870771          Loïc
#
#                                             comments language  sentiment  \
# 0  I've stayed with my friend at the Midtown Cast...       en     0.9248
# 1  We've been staying here for about 9 nights, en...       en     0.9229
# 2  We had a wonderful stay at Jennifer's charming...       en     0.9464
# 3  Hi to everyone!\r\nWould say our greatest comp...       en     0.9869
# 4  Jennifer was very friendly and helpful, and he...       en     0.9668
#
#    id_y neighbourhood_group_cleansed
# 0  2595                    Manhattan
# 1  2595                    Manhattan
# 2  2595                    Manhattan
# 3  2595                    Manhattan
# 4  2595                    Manhattan

# %%
df_merged.drop(columns=['id_y'], inplace=True)

# %%
df_avg_sent_borough = df_merged.groupby('neighbourhood_group_cleansed', group_keys=False, as_index=False).agg({'sentiment': np.mean})
df_avg_sent_borough
# Out:
#   neighbourhood_group_cleansed  sentiment
# 0                        Bronx   0.783458
# 1                     Brooklyn   0.835924
# 2                    Manhattan   0.819786
# 3                       Queens   0.785524
# 4                Staten Island   0.817085

# %%
x = df_avg_sent_borough['neighbourhood_group_cleansed']
plt.figure(figsize = (8,5))
sns.color_palette("husl", 8)
sns.set_palette('husl')
sns.set_style("darkgrid")
sns.barplot(x, y, palette='viridis')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-3166415905c3> in <module>
# ----> 1 x = df_avg_sent_borough['neighbourhood_group_cleansed']
#       2 plt.figure(figsize = (8,5))
#       3 sns.color_palette("husl", 8)
#       4 sns.set_palette('husl')
#       5 sns.set_style("darkgrid")
#
# NameError: name 'df_avg_sent_borough' is not defined

# %%
df_merged['sentiment_class'] = df_sent['sentiment'].apply(sentiment_classification)
df_avg_sent_borough = df_merged.groupby('neighbourhood_group_cleansed', group_keys=False, as_index=False).agg({'sentiment': np.mean})

# %% [markdown]
# ### Get distribution of languages of reviews

# %%
df_reviews_lang = pd.read_csv('reviews_with_lang.csv')
#count = df_reviews_lang.language.value_counts().iloc[:5]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-10b22ce4f04c> in <module>
#       1 df_reviews_lang = pd.read_csv('reviews_with_lang.csv')
#       2 count = df_reviews_lang.language.value_counts().iloc[:5]
# ----> 3 count.columns
#       4 #sns.barplot(count[0], count[1])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
sns.countplot(x='language',data=df_reviews_lang,order=pd.value_counts(df_reviews_lang['language']).iloc[:5].index, palette='viridis')

# %% [markdown]
# ## Generate word cloud

# %%
df = pd.read_csv('./Bristol/bristol_sentiment.csv')
df.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0       70820   8163487  2013-10-18      7538116       Neralee
# 1       70820   8397676  2013-10-28      9601180         Terry
# 2       70820   8706695  2013-11-12      9697980         Alice
# 3       70820  13024371  2014-05-17      2388955        Thomas
# 4       70820  14247963  2014-06-15     16317003     Dimitrije
#
#                                             comments language  sentiment
# 0  We loved our stay with Sarah in Bristol. She w...       en     0.9861
# 1  Sarah gave us and Laddie our dog a very warm w...       en     0.8712
# 2  Exactly as described on the site and praised b...       en     0.9336
# 3  Sarah was great. She was warm and welcoming, e...       en     0.9873
# 4  The experience was really great at Sarah's hou...       en     0.9875

# %%
plt.figure(figsize = (8,5))
sns.color_palette("husl", 8)
sns.set_palette('husl')
sns.set_style("darkgrid")
sns.distplot(df['sentiment'], kde = False, bins = 20)

# %%
df.shape
# Out:
# (67991, 8)

# %%
df_positive = df[df['sentiment']>.98]['comments']

# %%
df_neg = df[df['sentiment']<.05]['comments']

# %%
pos_text = ' '.join(list(df_positive))

post_text = pos_text.replace('\r','')
post_text = pos_text.replace('\n','')

# %%
neg_text = ' '.join(list(df_neg))

neg_text = neg_text.replace('\r','')
neg_text = neg_text.replace('\n','')

# %%
# Generate a word cloud image
wordcloud = WordCloud(background_color="white", max_words=200, contour_width=3, contour_color='steelblue')

wordcloud.generate(pos_text, )

# Display the generated image:
# the matplotlib way:
plt.figure(figsize = (8,5))
plt.title('Bristol Positive Word Cloud', fontsize=14, pad=15)
plt.imshow(wordcloud, interpolation='bilinear',)
plt.axis("off")
plt.savefig('./Bristol/bristol_pos_word_cloud.png', bbox_inches='tight')

# %%
# save wordcloud 

wordcloud.to_file('./Bristol/bristol_pos_word_cloud.png')

# %%
# Generate a word cloud image
wordcloud = WordCloud(background_color="white", max_words=200, contour_width=3, contour_color='steelblue')
wordcloud.generate(neg_text,)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.figure(figsize = (8,5))
plt.title('Bristol Negative Word Cloud', fontsize=14, pad=15)
plt.imshow(wordcloud, interpolation='bilinear',)
plt.axis("off")
plt.savefig('./Bristol/bristol_neg_word_cloud.png', bbox_inches='tight')
